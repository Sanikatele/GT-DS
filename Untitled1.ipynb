# %% [markdown]
# # **EDA ON TERRORISM BY SANIKA TELE**

# %% [markdown]
# **Importing** **all** **the** **libraries** **necessary** **for** **the** **analysis**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# **Importing and observing data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv("/content/drive/MyDrive/terrorism.csv", encoding="latin1")
df=pd.DataFrame(data)
print("Data has been successfully imported")
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,31,33,54,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Data has been successfully imported
#      ï»¿eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201183 entries, 0 to 201182
# Columns: 135 entries, ï»¿eventid to related
# dtypes: float64(53), int64(24), object(58)
# memory usage: 207.2+ MB

# %%
df.shape
# Out:
# (201183, 135)

# %%
df.columns
# Out:
# Index(['ï»¿eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in df.columns:
    print(i,end=", ")
# Out:
# ï»¿eventid, iyear, imonth, iday, approxdate, extended, resolution, country, country_txt, region, region_txt, provstate, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, alternative, alternative_txt, multiple, success, suicide, attacktype1, attacktype1_txt, attacktype2, attacktype2_txt, attacktype3, attacktype3_txt, targtype1, targtype1_txt, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, targtype2, targtype2_txt, targsubtype2, targsubtype2_txt, corp2, target2, natlty2, natlty2_txt, targtype3, targtype3_txt, targsubtype3, targsubtype3_txt, corp3, target3, natlty3, natlty3_txt, gname, gsubname, gname2, gsubname2, gname3, gsubname3, motive, guncertain1, guncertain2, guncertain3, individual, nperps, nperpcap, claimed, claimmode, claimmode_txt, claim2, claimmode2, claimmode2_txt, claim3, claimmode3, claimmode3_txt, compclaim, weaptype1, weaptype1_txt, weapsubtype1, weapsubtype1_txt, weaptype2, weaptype2_txt, weapsubtype2, weapsubtype2_txt, weaptype3, weaptype3_txt, weapsubtype3, weapsubtype3_txt, weaptype4, weaptype4_txt, weapsubtype4, weapsubtype4_txt, weapdetail, nkill, nkillus, nkillter, nwound, nwoundus, nwoundte, property, propextent, propextent_txt, propvalue, propcomment, ishostkid, nhostkid, nhostkidus, nhours, ndays, divert, kidhijcountry, ransom, ransomamt, ransomamtus, ransompaid, ransompaidus, ransomnote, hostkidoutcome, hostkidoutcome_txt, nreleased, addnotes, scite1, scite2, scite3, dbsource, INT_LOG, INT_IDEO, INT_MISC, INT_ANY, related,

# %% [markdown]
# **Cleaning** **the** **data**

# %%
df=df[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]
df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0  National  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                 gname motive weaptype1_txt  nkill  nwound  \
# 0                              MANO-D    NaN       Unknown    1.0     0.0
# 1  23rd of September Communist League    NaN       Unknown    0.0     0.0
# 2                             Unknown    NaN       Unknown    1.0     0.0
# 3                             Unknown    NaN    Explosives    NaN     NaN
# 4                             Unknown    NaN    Incendiary    NaN     NaN
#
#   addnotes
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",
                   "region_txt":"Region","provstate":"Province/State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location",
                   "summary":"Summary","attacktype1_txt":"Attack Type","targtype1_txt":"Target Type",
                   "gname":"Group Name","motive":"Motive","weaptype1_txt":"Weapon Type",
                   "nkill":"Killed","nwound":"Wounded","addnotes":"Add Notes"},inplace=True)

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0       National  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                            Group Name Motive Weapon Type  Killed  Wounded  \
# 0                              MANO-D    NaN     Unknown     1.0      0.0
# 1  23rd of September Communist League    NaN     Unknown     0.0      0.0
# 2                             Unknown    NaN     Unknown     1.0      0.0
# 3                             Unknown    NaN  Explosives     NaN      NaN
# 4                             Unknown    NaN  Incendiary     NaN      NaN
#
#   Add Notes
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201183 entries, 0 to 201182
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            201183 non-null  int64
#  1   Month           201183 non-null  int64
#  2   Day             201183 non-null  int64
#  3   Country         201183 non-null  object
#  4   Region          201183 non-null  object
#  5   Province/State  201183 non-null  object
#  6   City            200757 non-null  object
#  7   Latitude        196556 non-null  float64
#  8   Longitude       196555 non-null  float64
#  9   Location        63769 non-null   object
#  10  Summary         135062 non-null  object
#  11  Attack Type     201183 non-null  object
#  12  Target Type     201183 non-null  object
#  13  Group Name      201183 non-null  object
#  14  Motive          53629 non-null   object
#  15  Weapon Type     201183 non-null  object
#  16  Killed          189233 non-null  float64
#  17  Wounded         182259 non-null  float64
#  18  Add Notes       33447 non-null   object
# dtypes: float64(4), int64(3), object(12)
# memory usage: 29.2+ MB

# %%
df.shape
# Out:
# (201183, 19)

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State         0
# City                 426
# Latitude            4627
# Longitude           4628
# Location          137414
# Summary            66121
# Attack Type            0
# Target Type            0
# Group Name             0
# Motive            147554
# Weapon Type            0
# Killed             11950
# Wounded            18924
# Add Notes         167736
# dtype: int64

# %%
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df["Casualty"]=df["Killed"]+df["Wounded"]

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  201183.000000  201183.000000  201183.000000  196556.000000
# mean     2004.158478       6.451678      15.520983      23.356215
# std        13.429481       3.387376       8.808477      18.224189
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1992.000000       4.000000       8.000000      11.506724
# 50%      2011.000000       6.000000      15.000000      31.250196
# 75%      2015.000000       9.000000      23.000000      34.558524
# max      2019.000000      12.000000      31.000000      74.633553
#
#            Longitude         Killed        Wounded       Casualty
# count  196555.000000  201183.000000  201183.000000  201183.000000
# mean       29.784881       2.267831       2.831964       5.099795
# std        56.602962      10.927856      39.728346      45.662265
# min      -176.176447       0.000000       0.000000       0.000000
# 25%         8.644191       0.000000       0.000000       0.000000
# 50%        43.659053       0.000000       0.000000       1.000000
# 75%        68.810806       2.000000       2.000000       4.000000
# max       179.366667    1570.000000   10878.000000   12263.000000

# %% [markdown]
# Observation:
#
# The data consists of terrorist activities ranging from the year: 1970 to 2017
# Maximum number of people killed in an event were: 1570
# Maximum number of people wounded in an event were: 8191
# Maximum number of total casualties in an event were: 9574

# %% [markdown]
# **Visualizing** **the** **data**
# 1. Year wise Attacks
#
#         Number of Attacks in each Year

# %%
attacks=df["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
attacks.head()
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581

# %%
attacks.plot(kind="bar",color="pink",figsize=(15,6),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# (i)Most number of attacks(16903) in 2014
#
# (ii). Least number of attacks(471) in 1971

# %% [markdown]
# Total Casualties (Killed + Wounded) in each Year

# %%
yc=df[["Year","Casualty"]].groupby("Year").sum()
yc.head()
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0

# %%
yc.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Year wise Casualties",fontsize=13)
plt.xlabel("Years",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# Killed in each Year

# %%
yk=df[["Year","Killed"]].groupby("Year").sum()
yk.head()
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %% [markdown]
# Wounded in each Region

# %%
yw=df[["Year","Wounded"]].groupby("Year").sum()
yw.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#Killed
yk.plot(kind="bar",color="pink",figsize=(15,15),ax=ax0)
ax0.set_title("People Killed in each Year")
ax0.set_xlabel("Years")
ax0.set_ylabel("Number of People Killed") 

#Wounded
yw.plot(kind="bar",color="pink",figsize=(15,15),ax=ax1)
ax1.set_title("People Wounded in each Year")
ax1.set_xlabel("Years")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# **Region** **wise** **Attacks**

# %% [markdown]
# Distribution of Terrorist Attacks over Regions from 1970-2017

# %%
reg=pd.crosstab(df.Year,df.Region)
reg.head()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          28            472
# 1971            1               5                          55            247
# 1972            0               1                          53             73
# 1973            2               1                          19             64
# 1974            4               2                          42            111
#
# Region  South America  South Asia  Southeast Asia  Sub-Saharan Africa  \
# Year
# 1970               65           1              10                   3
# 1971               24           0               6                   2
# 1972               33           1              16                   4
# 1973               83           1               2                   4
# 1974               81           2               3                   7
#
# Region  Western Europe
# Year
# 1970                50
# 1971               125
# 1972               376
# 1973               290
# 1974               317

# %%
reg.plot(kind="area", stacked=False, alpha=0.5,figsize=(20,10))
plt.title("Region wise attacks",fontsize=20)
plt.xlabel("Years",fontsize=20)
plt.ylabel("Number of Attacks",fontsize=20)
plt.show()

# %% [markdown]
# Total Terrorist Attacks in each Region from 1970-2017

# %%
regt=reg.transpose()
regt["Total"]=regt.sum(axis=1)
ra=regt["Total"].sort_values(ascending=False)
ra
# Out:
# Region
# Middle East & North Africa     56414
# South Asia                     51301
# Sub-Saharan Africa             21742
# South America                  19572
# Western Europe                 17033
# Southeast Asia                 14079
# Central America & Caribbean    10374
# Eastern Europe                  5266
# North America                   3698
# East Asia                        825
# Central Asia                     574
# Australasia & Oceania            305
# Name: Total, dtype: int64

# %%
ra.plot(kind="bar",figsize=(15,6))
plt.title("Total Number of Attacks in each Region from 1970-2017")
plt.xlabel("Region")
plt.ylabel("Number of Attacks")
plt.show()

# %% [markdown]
# Total Casualties (Killed + Wounded) in each Region

# %%
rc=df[["Region","Casualty"]].groupby("Region").sum().sort_values(by="Casualty",ascending=False)
rc
# Out:
#                              Casualty
# Region
# Middle East & North Africa   372683.0
# South Asia                   281859.0
# Sub-Saharan Africa           151211.0
# South America                 46559.0
# Southeast Asia                44761.0
# Central America & Caribbean   37740.0
# North America                 32291.0
# Western Europe                25325.0
# Eastern Europe                19552.0
# East Asia                     10391.0
# Central Asia                   3104.0
# Australasia & Oceania           516.0

# %%
rc.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Region wise Casualties",fontsize=13)
plt.xlabel("Regions",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# Killed in each Region

# %%
rk=df[["Region","Killed"]].groupby("Region").sum().sort_values(by="Killed",ascending=False)
rk
# Out:
#                                Killed
# Region
# Middle East & North Africa   146914.0
# South Asia                   121322.0
# Sub-Saharan Africa            91588.0
# South America                 29195.0
# Central America & Caribbean   28723.0
# Southeast Asia                16834.0
# Eastern Europe                 7468.0
# Western Europe                 6669.0
# North America                  5095.0
# East Asia                      1154.0
# Central Asia                   1084.0
# Australasia & Oceania           203.0

# %% [markdown]
# Wounded in each Region

# %%
rw=df[["Region","Wounded"]].groupby("Region").sum().sort_values(by="Wounded",ascending=False)
rw
# Out:
#                               Wounded
# Region
# Middle East & North Africa   225769.0
# South Asia                   160537.0
# Sub-Saharan Africa            59623.0
# Southeast Asia                27927.0
# North America                 27196.0
# Western Europe                18656.0
# South America                 17364.0
# Eastern Europe                12084.0
# East Asia                      9237.0
# Central America & Caribbean    9017.0
# Central Asia                   2020.0
# Australasia & Oceania           313.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
rk.plot(kind="bar",color="pink",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Region")
ax0.set_xlabel("Regions")
ax0.set_ylabel("Number of People Killed")

#Wounded
rw.plot(kind="bar",color="pink",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Region")
ax1.set_xlabel("Regions")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# **Country** **wise** **Attacks** - **Top** **10**

# %% [markdown]
# Number of Attacks in each Country

# %%
ct=df["Country"].value_counts().head(10)
ct
# Out:
# Iraq              26755
# Afghanistan       16313
# Pakistan          15208
# India             13477
# Colombia           8742
# Philippines        7976
# Peru               6109
# Yemen              5526
# United Kingdom     5424
# El Salvador        5320
# Name: Country, dtype: int64

# %%
ct.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Country wise Attacks",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# Total Casualties (Killed + Wounded) in each Country

# %%
cnc=df[["Country","Casualty"]].groupby("Country").sum().sort_values(by="Casualty",ascending=False)
cnc.head(10)
# Out:
#                Casualty
# Country
# Iraq           219355.0
# Afghanistan    117200.0
# Pakistan        69160.0
# India           50210.0
# Nigeria         38834.0
# Syria           34633.0
# Sri Lanka       31321.0
# United States   30159.0
# Colombia        25751.0
# Philippines     24803.0

# %%
cnc[:10].plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Country wie Casualties",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# Killed in each Country

# %%
cnk=df[["Country","Killed"]].groupby("Country").sum().sort_values(by="Killed",ascending=False)
cnk.head(10)
# Out:
#               Killed
# Country
# Iraq         81019.0
# Afghanistan  57453.0
# Nigeria      26997.0
# Pakistan     24935.0
# India        20066.0
# Syria        17886.0
# Sri Lanka    15588.0
# Colombia     14963.0
# Peru         12778.0
# Somalia      12290.0

# %% [markdown]
# Wounded in each Country

# %%
cnw=df[["Country","Wounded"]].groupby("Country").sum().sort_values(by="Wounded",ascending=False)
cnw.head(10)
# Out:
#                 Wounded
# Country
# Iraq           138336.0
# Afghanistan     59747.0
# Pakistan        44225.0
# India           30144.0
# United States   26269.0
# Syria           16747.0
# Sri Lanka       15733.0
# Philippines     14404.0
# Yemen           12534.0
# Nigeria         11837.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
cnk[:10].plot(kind="bar",color="pink",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Country")
ax0.set_xlabel("Countries")
ax0.set_ylabel("Number of People Killed")

#Wounded
cnw[:10].plot(kind="bar",color="pink",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Country")
ax1.set_xlabel("Countries")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# **City** **wise**  **Attacks** - **Top** **10**

# %% [markdown]
# Number of Attacks in each city

# %%
city=df["City"].value_counts()[1:11]
city
# Out:
# Baghdad         7881
# Karachi         2698
# Lima            2359
# Mosul           2326
# Belfast         2230
# Mogadishu       1885
# Santiago        1637
# San Salvador    1560
# Athens          1059
# Istanbul        1056
# Name: City, dtype: int64

# %%
city.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("City wise Attacks",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# Total Casualties (Killed + Wounded) in each City

# %%
cc=df[["City","Casualty"]].groupby("City").sum().sort_values(by="Casualty",ascending=False).drop("Unknown")
cc.head(10)
# Out:
#                Casualty
# City
# Baghdad         78977.0
# New York City   25014.0
# Mosul           13250.0
# Kabul           11912.0
# Mogadishu       10522.0
# Karachi          9457.0
# Beirut           7302.0
# Kirkuk           6848.0
# Colombo          6221.0
# Quetta           6014.0

# %%
cc[:10].plot(kind="bar",color="pink",figsize=(15,6))
plt.title("City wise Casualties",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# Killed in each City

# %%
ck=df[["City","Killed"]].groupby("City").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
ck.head(10)
# Out:
#                 Killed
# City
# Baghdad        21395.0
# Mosul           7279.0
# Mogadishu       4617.0
# Karachi         3730.0
# Kabul           3537.0
# New York City   2844.0
# Tikrit          2692.0
# Maiduguri       2366.0
# Ramadi          2312.0
# Aleppo          2194.0

# %% [markdown]
# Wounded in each City

# %%
cw=df[["City","Wounded"]].groupby("City").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
cw.head(10)
# Out:
#                Wounded
# City
# Baghdad        57582.0
# New York City  22170.0
# Kabul           8375.0
# Mosul           5971.0
# Mogadishu       5905.0
# Karachi         5727.0
# Tokyo           5550.0
# Beirut          5396.0
# Kirkuk          5183.0
# Nairobi         5055.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
ck[:10].plot(kind="bar",color="pink",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each City")
ax0.set_xlabel("Cities")
ax0.set_ylabel("Number of People Killed")

#Wounded
cw[:10].plot(kind="bar",color="pink",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each City")
ax1.set_xlabel("Cities")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# **Terrorist** **Group** **wise** **Attacks** - **Top** **10**

# %% [markdown]
# Number of Attacks by each Group

# %%
grp=df["Group Name"].value_counts()[1:10]
grp
# Out:
# Taliban                                             10094
# Islamic State of Iraq and the Levant (ISIL)          6864
# Shining Path (SL)                                    4563
# Al-Shabaab                                           4126
# Farabundo Marti National Liberation Front (FMLN)     3351
# New People's Army (NPA)                              3249
# Boko Haram                                           3018
# Houthi extremists (Ansar Allah)                      2776
# Irish Republican Army (IRA)                          2669
# Name: Group Name, dtype: int64

# %%
grp.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Group wise Attacks",fontsize=13)
plt.xlabel("Terrorist Groups",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# Total Casualties(Killed + Wounded) by each Group

# %%
gc=df[["Group Name","Casualty"]].groupby("Group Name").sum().sort_values(by="Casualty",ascending=False).drop("Unknown")
gc.head(10)
# Out:
#                                                   Casualty
# Group Name
# Taliban                                            84323.0
# Islamic State of Iraq and the Levant (ISIL)        76703.0
# Boko Haram                                         34651.0
# Al-Qaida                                           33753.0
# Liberation Tigers of Tamil Eelam (LTTE)            21474.0
# Al-Shabaab                                         20747.0
# Tehrik-i-Taliban Pakistan (TTP)                    16303.0
# Al-Qaida in Iraq                                   14724.0
# Shining Path (SL)                                  14644.0
# Farabundo Marti National Liberation Front (FMLN)   12130.0

# %%
gc.head(10).plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Casualties by each Group",fontsize=13)
plt.xlabel("Terrorist Groups",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# Killed by each Group

# %%
gk=df[["Group Name","Killed"]].groupby("Group Name").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
gk.head(10)
# Out:
#                                                    Killed
# Group Name
# Taliban                                           45210.0
# Islamic State of Iraq and the Levant (ISIL)       42505.0
# Boko Haram                                        23637.0
# Shining Path (SL)                                 11608.0
# Al-Shabaab                                        11372.0
# Liberation Tigers of Tamil Eelam (LTTE)           10778.0
# Farabundo Marti National Liberation Front (FMLN)   8065.0
# Nicaraguan Democratic Force (FDN)                  6662.0
# Tehrik-i-Taliban Pakistan (TTP)                    6311.0
# Revolutionary Armed Forces of Colombia (FARC)      5661.0

# %% [markdown]
# Wounded by each Group

# %%
gw=df[["Group Name","Wounded"]].groupby("Group Name").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
gw.head(10)
# Out:
#                                              Wounded
# Group Name
# Taliban                                      39113.0
# Islamic State of Iraq and the Levant (ISIL)  34198.0
# Al-Qaida                                     29890.0
# Boko Haram                                   11014.0
# Liberation Tigers of Tamil Eelam (LTTE)      10696.0
# Al-Qaida in Iraq                             10343.0
# Tehrik-i-Taliban Pakistan (TTP)               9992.0
# Al-Shabaab                                    9375.0
# Aum Shinri Kyo                                6003.0
# Houthi extremists (Ansar Allah)               5957.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
gk[:10].plot(kind="bar",color="pink",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed by each Group")
ax0.set_xlabel("Terrorist Groups")
ax0.set_ylabel("Number of people Killed")

#Wounded
gw[:10].plot(kind="bar",color="pink",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded by each Group")
ax1.set_xlabel("Terrorist Groups")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
#  **Attack** **Type** **wise** **Attacks**

# %% [markdown]
# Number of Attacks by each Attack Type

# %%
at=df["Attack Type"].value_counts()
at
# Out:
# Bombing/Explosion                      95402
# Armed Assault                          47419
# Assassination                          20897
# Hostage Taking (Kidnapping)            13198
# Facility/Infrastructure Attack         11636
# Unknown                                 9590
# Unarmed Assault                         1183
# Hostage Taking (Barricade Incident)     1124
# Hijacking                                734
# Name: Attack Type, dtype: int64

# %%
at.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Types of Attacks",fontsize=13)
plt.xlabel("Attack Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# Total Casualties (Killed + Wounded) by each Attack Type

# %%
ac=df[["Attack Type","Casualty"]].groupby("Attack Type").sum().sort_values(by="Casualty",ascending=False)
ac
# Out:
#                                      Casualty
# Attack Type
# Bombing/Explosion                    565111.0
# Armed Assault                        260537.0
# Unknown                               61767.0
# Assassination                         42133.0
# Hostage Taking (Kidnapping)           37163.0
# Hijacking                             26149.0
# Unarmed Assault                       15597.0
# Hostage Taking (Barricade Incident)    9243.0
# Facility/Infrastructure Attack         8292.0

# %%
ac.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Casualties in each Attack",fontsize=13)
plt.xlabel("Attack Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# Killed by each Attack Type

# %%
ak=df[["Attack Type","Killed"]].groupby("Attack Type").sum().sort_values(by="Killed",ascending=False)
ak
# Out:
#                                        Killed
# Attack Type
# Armed Assault                        174916.0
# Bombing/Explosion                    169961.0
# Unknown                               42035.0
# Hostage Taking (Kidnapping)           28816.0
# Assassination                         26681.0
# Hostage Taking (Barricade Incident)    4912.0
# Facility/Infrastructure Attack         4274.0
# Hijacking                              3735.0
# Unarmed Assault                         919.0

# %% [markdown]
# Wounded by each Attack Type

# %%
aw=df[["Attack Type","Wounded"]].groupby("Attack Type").sum().sort_values(by="Wounded",ascending=False)
aw
# Out:
#                                       Wounded
# Attack Type
# Bombing/Explosion                    395150.0
# Armed Assault                         85621.0
# Hijacking                             22414.0
# Unknown                               19732.0
# Assassination                         15452.0
# Unarmed Assault                       14678.0
# Hostage Taking (Kidnapping)            8347.0
# Hostage Taking (Barricade Incident)    4331.0
# Facility/Infrastructure Attack         4018.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
ak.plot(kind="bar",color="pink",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Attack Type")
ax0.set_xlabel("Attack Types")
ax0.set_ylabel("Number of people Killed")

#Wounded
aw.plot(kind="bar",color="pink",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Attack Type")
ax1.set_xlabel("Attack Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# **Target** **Type** **wise** **Attacks**

# %% [markdown]
# Number of Attacks over each Target Type

# %%
ta=df["Target Type"].value_counts()
ta
# Out:
# Private Citizens & Property       49495
# Military                          31998
# Police                            27273
# Government (General)              23174
# Business                          21797
# Transportation                     7075
# Unknown                            6815
# Utilities                          6232
# Religious Figures/Institutions     4917
# Educational Institution            4658
# Government (Diplomatic)            3738
# Terrorists/Non-State Militia       3523
# Journalists & Media                3213
# Violent Political Party            2051
# Airports & Aircraft                1395
# Telecommunication                  1137
# NGO                                1078
# Tourists                            455
# Maritime                            387
# Food or Water Supply                343
# Abortion Related                    265
# Other                               164
# Name: Target Type, dtype: int64

# %%
ta.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Types of Targets",fontsize=13)
plt.xlabel("Target Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %%
tc=df[["Target Type","Casualty"]].groupby("Target Type").sum().sort_values(by="Casualty",ascending=False)
tc
# Out:
#                                 Casualty
# Target Type
# Private Citizens & Property     349704.0
# Military                        200490.0
# Police                          134598.0
# Business                         82407.0
# Government (General)             73491.0
# Transportation                   55446.0
# Religious Figures/Institutions   40167.0
# Terrorists/Non-State Militia     20318.0
# Educational Institution          14619.0
# Government (Diplomatic)          14310.0
# Violent Political Party           9152.0
# Unknown                           8472.0
# Airports & Aircraft               7299.0
# Journalists & Media               3592.0
# Utilities                         3327.0
# NGO                               2155.0
# Maritime                          2138.0
# Tourists                          2128.0
# Other                              790.0
# Telecommunication                  717.0
# Food or Water Supply               616.0
# Abortion Related                    56.0

# %%
tc.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Casualties in each Target Attack",fontsize=13)
plt.xlabel("Target Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %%
tk=df[["Target Type","Killed"]].groupby("Target Type").sum().sort_values(by="Killed",ascending=False)
tk
# Out:
#                                   Killed
# Target Type
# Private Citizens & Property     153607.0
# Military                        119965.0
# Police                           62271.0
# Government (General)             28916.0
# Business                         24904.0
# Religious Figures/Institutions   14270.0
# Transportation                   14238.0
# Terrorists/Non-State Militia     10847.0
# Unknown                           4887.0
# Educational Institution           3969.0
# Airports & Aircraft               3731.0
# Violent Political Party           3726.0
# Government (Diplomatic)           3344.0
# Utilities                         1945.0
# Journalists & Media               1641.0
# Maritime                          1212.0
# NGO                               1142.0
# Tourists                           778.0
# Food or Water Supply               348.0
# Other                              293.0
# Telecommunication                  205.0
# Abortion Related                    10.0

# %%
tw=df[["Target Type","Wounded"]].groupby("Target Type").sum().sort_values(by="Wounded",ascending=False)
tw
# Out:
#                                  Wounded
# Target Type
# Private Citizens & Property     196097.0
# Military                         80525.0
# Police                           72327.0
# Business                         57503.0
# Government (General)             44575.0
# Transportation                   41208.0
# Religious Figures/Institutions   25897.0
# Government (Diplomatic)          10966.0
# Educational Institution          10650.0
# Terrorists/Non-State Militia      9471.0
# Violent Political Party           5426.0
# Unknown                           3585.0
# Airports & Aircraft               3568.0
# Journalists & Media               1951.0
# Utilities                         1382.0
# Tourists                          1350.0
# NGO                               1013.0
# Maritime                           926.0
# Telecommunication                  512.0
# Other                              497.0
# Food or Water Supply               268.0
# Abortion Related                    46.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
tk.plot(kind="bar",color="pink",figsize=(17,6),ax=ax0)
ax0.set_title("People Killed in each Target Attack")
ax0.set_xlabel("Target Types")
ax0.set_ylabel("Number of people Killed")

#Wounded
tw.plot(kind="bar",color="pink",figsize=(17,6),ax=ax1)
ax1.set_title("People Wounded in each Target Attack")
ax1.set_xlabel("Target Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# **Group** + **Country** **wise** - **Top10**

# %% [markdown]
# Sorting by number of Attacks

# %%
gca=df[["Group Name","Country"]].value_counts().drop("Unknown")
gca.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# Group Name                                        Country
# Taliban                                           Afghanistan       10038
# Islamic State of Iraq and the Levant (ISIL)       Iraq               5857
# Shining Path (SL)                                 Peru               4549
# Al-Shabaab                                        Somalia            3618
# Farabundo Marti National Liberation Front (FMLN)  El Salvador        3330
# New People's Army (NPA)                           Philippines        3247
# Irish Republican Army (IRA)                       United Kingdom     2574
# Boko Haram                                        Nigeria            2571
# Houthi extremists (Ansar Allah)                   Yemen              2485
# Revolutionary Armed Forces of Colombia (FARC)     Colombia           2468
# dtype: int64

# %%
gca.head(10).plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Countries with most attacks by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# Sorting by Number of Casualties

# %%
gcc=df[["Group Name","Country","Casualty"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Casualty",ascending=False).drop("Unknown").head(10)
gcc
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                                                            Casualty
# Group Name                                  Country
# Taliban                                     Afghanistan     84118.0
# Islamic State of Iraq and the Levant (ISIL) Iraq            58572.0
# Boko Haram                                  Nigeria         28109.0
# Al-Qaida                                    United States   24875.0
# Liberation Tigers of Tamil Eelam (LTTE)     Sri Lanka       21373.0
# Al-Shabaab                                  Somalia         17734.0
# Tehrik-i-Taliban Pakistan (TTP)             Pakistan        16243.0
# Shining Path (SL)                           Peru            14637.0
# Al-Qaida in Iraq                            Iraq            14348.0
# Islamic State of Iraq and the Levant (ISIL) Syria           13131.0

# %%
gcc.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Countries with most casualties by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# orting by Number of People Killed

# %%
gck=df[["Group Name","Country","Killed"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(10)
gck
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                                                                Killed
# Group Name                                       Country
# Taliban                                          Afghanistan  45067.0
# Islamic State of Iraq and the Levant (ISIL)      Iraq         32829.0
# Boko Haram                                       Nigeria      19240.0
# Shining Path (SL)                                Peru         11602.0
# Liberation Tigers of Tamil Eelam (LTTE)          Sri Lanka    10717.0
# Al-Shabaab                                       Somalia      10088.0
# Islamic State of Iraq and the Levant (ISIL)      Syria         8296.0
# Farabundo Marti National Liberation Front (FMLN) El Salvador   8019.0
# Nicaraguan Democratic Force (FDN)                Nicaragua     6630.0
# Tehrik-i-Taliban Pakistan (TTP)                  Pakistan      6269.0

# %%
gck.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Countries with most people killed by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of people Killed",fontsize=13)
plt.show()

# %% [markdown]
# Sorting by Number of People Wounded

# %%
gcw=df[["Group Name","Country","Wounded"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Wounded",ascending=False).drop("Unknown").head(10)
gcw
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                                                            Wounded
# Group Name                                  Country
# Taliban                                     Afghanistan    39051.0
# Islamic State of Iraq and the Levant (ISIL) Iraq           25743.0
# Al-Qaida                                    United States  21871.0
# Liberation Tigers of Tamil Eelam (LTTE)     Sri Lanka      10656.0
# Al-Qaida in Iraq                            Iraq           10075.0
# Tehrik-i-Taliban Pakistan (TTP)             Pakistan        9974.0
# Boko Haram                                  Nigeria         8869.0
# Al-Shabaab                                  Somalia         7646.0
# Aum Shinri Kyo                              Japan           6003.0
# Houthi extremists (Ansar Allah)             Yemen           5608.0

# %%
gcw.plot(kind="bar",color="pink",figsize=(15,6))
plt.title("Countries with most people wounded by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of people Wounded",fontsize=13)
plt.show()

# %% [markdown]
# **Humanity** **Affected** (**World**-**wide**) **by** **Terrorist** **Attacks** **from** **1970** **to** **2017**

# %% [markdown]
# Total Casualties (Killed + Wounded) due to Terrorist Attacks

# %%
casualty=df.loc[:,"Casualty"].sum()
print("Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world :\n",casualty)
# Out:
# Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world :
#  1025992.0

# %% [markdown]
# Killed due to Terrorist Attacks

# %%
kill=df.loc[:,"Killed"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",kill)

# %% [markdown]
# Wounded due to Terrorist Attacks

# %%
wound=df.loc[:,"Wounded"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",wound)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  569743.0

# %% [markdown]
# # Observations

# %% [markdown]
# Year wise Attacks :
#
#   (i) Attacks
#
#     (a) Most number of attacks: 16903 in 2014
#
#     (b) Least number of attacks: 471 in 1971
#
#   (ii) Casualties
#
#     (a) Most number of casualties: 85618 in 2014
#
#     (b) Least number of casualties: 255 in 1971
#
#   (iii) Killed
#
#     (a) Most number of people killed: 44490 in 2014
#
#     (b) Least number of people killed: 173 in 1971
#
#   (iv) Wounded
#
#     (a) Most number of people wounded: 44043 in 2015
#
#     (b) Least number of people wounded: 82 in 1971

# %% [markdown]
# Region wise Attacks :
#
#   (i) Attacks
#
#     (a) Most number of attacks: 50474 in "Middle East & North Africa"
#
#     (b) Least number of attacks: 282 in "Australasia & Oceania"
#
#   (ii) Casualties
#
#     (a) Most number of casualties: 351950 in "Middle East & North Africa"
#
#     (b) Least number of casualties: 410 in Australasia & Oceania
#
#   (iii) Killed
#
#     (a) Most number of people killed: 137642 in "Middle East & North Africa"
#
#     (b) Least number of people killed: 150 in "Australasia & Oceania"
#
#   (iv) Wounded
#
#     (a) Most number of people wounded: 214308 in "Middle East & North Africa"
#
#     (b) Least number of people wounded: 260 in "Australasia & Oceania"

# %% [markdown]
# Country wise Attacks [Top 10] :
#
#   (i) Attacks
#
#     (a) Most number of attacks: 24636 in "Iraq"
#
#     (b) Least number of attacks: 4292 in "Turkey"
#
#   (ii) Casualties
#
#     (a) Most number of casualties: 213279 in "Iraq"
#
#     (b) Least number of casualties: 22926 in "Philippines"
#
#   (iii) Killed
#
#     (a) Most number of people killed: 78589 in "Iraq"
#
#     (b) Least number of people killed: 12053 in "El Salvador"
#
#   (iv) Wounded
#
#     (a) Most number of people wounded: 134690 in "Iraq"
#
#     (b) Least number of people wounded: 10328 in "Colombia"

# %% [markdown]
# City wise Attacks [Top 10] :
#
#   (i) Attacks
#
#     (a) Most number of attacks: 7589 in "Baghdad"
#
#     (b) Least number of attacks: 1019 in "Athens"
#
#   (ii) Casualties
#
#     (a) Most number of casualties: 77876 in "Baghdad"
#
#     (b) Least number of casualties: 5748 in "Aleppo"
#
#   (iii) Killed
#
#     (a) Most number of people killed: 21151 in "Baghdad"
#
#     (b) Least number of people killed: 2125 in "Aleppo"
#
#   (iv) Wounded
#
#     (a) Most number of people wounded: 56725 in "Baghdad"
#
#     (b) Least number of people wounded: 4955 in "Mogadishu"

# %% [markdown]
# Terrorist Group wise Attacks [Top 10] :
#
#   (i) Attacks
#
#     (a) Most number of attacks : 7478 by "Taliban"
#
#     (b) Least number of attacks : 2418 by "Boko Haram"
#
#   (ii) Casualties
#
#     (a) Most number of casualties : 69595 by "Islamic State of Iraq and the Levant (ISIL)"
#
#     (b) Least number of casualties : 12130 by "Farabundo Marti National Liberation Front (FMLN)"
#
#   (iii) Killed
#
#     (a) Most number of people killed : 38923 by "Islamic State of Iraq and the Levant (ISIL)"
#
#     (b) Least number of people killed : 5661 by "Revolutionary Armed Forces of Colombia (FARC)"
#
#   (iv) Wounded
#
#     (a) Most number of people wounded : 30672 by "Islamic State of Iraq and the Levant (ISIL)"
#
#     (b) Least number of people wounded : 4908 by "Kurdistan Workers' Party (PKK)"

# %% [markdown]
# Attack Type wise Attacks:
#
#   (i) Attacks
#
#     (a) Most number of attacks : 88255 by "Bombing/Explosion"
#
#     (b) Least number of attacks : 659 by "Hijacking"
#
#   (ii) Casualties
#
#     (a) Most number of casualties : 530007 by "Bombing/Explosion"
#
#     (b) Least number of casualties : 7407 by "Facility/Infrastructure Attack"
#
#   (iii) Killed
#
#     (a) Most number of people killed : 160297 by "Armed Assault"
#
#     (b) Least number of people killed : 880 by "Unarmed Assault"
#
#   (iv) Wounded
#
#     (a) Most number of people wounded : 372686 by "Bombing/Explosion"
#
#     (b) Least number of people wounded : 3765 by "Facility/Infrastructure Attack"

# %% [markdown]
# Target Type wise Attacks:
#
#   (i) Attacks
#
#     (a) Most number of attacks : 43511 over "Private Citizens & Property"
#
#     (b) Least number of attacks : 263 over "Abortion Related"
#
#   (ii) Casualties
#
#     (a) Most number of casualties : 319176 over "Private Citizens & Property"
#
#     (b) Least number of casualties : 56 over "Abortion Related"
#
#   (iii) Killed
#
#     (a) Most number of people killed : 140504 over "Private Citizens & Property"
#
#     (b) Least number of people killed : 10 over "Abortion Related"
#
#   (iv) Wounded
#
#     (a) Most number of people wounded : 178672 over "Private Citizens & Property"
#
#     (b) Least number of people wounded : 46 over "Abortion Related"

# %% [markdown]
# Group and Country wise Attacks [Top 10] :
#
#   (i) Attacks
#
#     (a) Most number of attacks : 7423 by "Taliban" in "Afghanistan"
#
#     (b) Least number of attacks : 2087 by "Boko Haram" in "Nigeria"
#
#   (ii) Casualties
#
#     (a) Most number of casualties : 57140 by "Taliban" in "Afghanistan"
#
#     (b) Least number of casualties : 12068 by "Farabundo Marti National Liberation Front (FMLN)" in "El Salvador"
#
#   (iii) Killed
#
#     (a) Most number of people killed : 31058 by "Islamic State of Iraq and the Levant (ISIL)" in "Iraq"
#
#     (b) Least number of people killed : 6014 by "Tehrik-i-Taliban Pakistan (TTP)" in "Pakistan"
#
#   (iv) Wounded
#
#     (a) Most number of people wounded : 27871 by "Taliban" in "Afghanistan"
#
#     (b) Least number of people wounded : 4795 by "Kurdistan Workers' Party (PKK)" in "Turkey"

# %% [markdown]
# Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017 :
#
#   (i) Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world : 935737
#
#   (ii) Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : 411868
#
#   (iii) Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : 523869
